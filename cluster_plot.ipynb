# %%
import matplotlib.pyplot as plt 
import pandas as pd

# %%
df = pd.read_csv('Dataset_to_plot.csv')
df.head(10)
# Out:
#    Unnamed: 0  index                                        Movie  P_Genre  \
# 0           0      0                              stranger things        1
# 1           1      1                                     the boys        0
# 2           2      2                                resident evil        0
# 3           3      3                         the umbrella academy        0
# 4           4      4                                   ms. marvel        0
# 5           5      5                                    westworld        1
# 6           6      6                      jurassic world dominion        0
# 7           7      7                     minions: the rise of gru       11
# 8           8      8  doctor strange in the multiverse of madness        0
# 9           9      9            everything everywhere all at once        0
#
#    S_Genre  T_Genre  Cluster_Id
# 0        8       14          55
# 1        3        1         184
# 2       15        8          23
# 3        5        2           2
# 4        5        2           2
# 5        4        8         168
# 6        5        8           8
# 7        5        2          12
# 8        5        9          37
# 9        5        2           2

# %%
def data_plot(data):

    fig = plt.figure(figsize=(15,10))
    ax = fig.add_subplot(projection='3d')

    g = ax.scatter(data["P_Genre"], data["S_Genre"], data["T_Genre"], c = data['Cluster_Id'])
    ax.set_xlabel("P_Genre")
    ax.set_ylabel("S_Genre")
    ax.set_zlabel("T_Genre")
    plt.show()

# %%
data_plot(df)
